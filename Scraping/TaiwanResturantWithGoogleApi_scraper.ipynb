# %%
! pip install -U googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.6.0.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\mason89823\anaconda3\lib\site-packages (from googlemaps) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mason89823\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mason89823\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mason89823\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mason89823\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38552 sha256=b86c8d831dbd520d3e37f922e1baf5ece15b4804e129e632006ac261d1ea3625
#   Stored in directory: c:\users\mason89823\appdata\local\pip\cache\wheels\b6\23\aa\a130b53682531f8382dd06f2000001225bea7b56a99c516f87
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.6.0

# %%
import googlemaps
import pandas as pd
import time
from pprint import pprint
gmaps = googlemaps.Client(key='AIzaSyCJevRqwfcHT2PmkBejxd-DFXMWsnz0rt8')

# %%
cities= ["臺北市","新北市","桃園市","臺中市","臺南市","高雄市","基隆市","新竹市","嘉義市","新竹縣",
        "苗栗縣","彰化縣","南投縣","雲林縣","嘉義縣","屏東縣","宜蘭縣","花蓮縣","臺東縣","澎湖縣"]

# %%
geocode_result = gmaps.geocode("臺北市")
pprint(geocode_result)
# Out:
# [{'address_components': [{'long_name': 'Taipei',
#                           'short_name': 'Taipei',
#                           'types': ['colloquial_area',
#                                     'locality',
#                                     'political']},
#                          {'long_name': 'Taiwan',
#                           'short_name': 'TW',
#                           'types': ['country', 'political']}],
#   'formatted_address': 'Taipei, Taiwan',
#   'geometry': {'bounds': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#                           'southwest': {'lat': 24.7900797, 'lng': 121.2826735}},
#                'location': {'lat': 25.0329694, 'lng': 121.5654177},
#                'location_type': 'APPROXIMATE',
#                'viewport': {'northeast': {'lat': 25.2443731,
#                                           'lng': 121.7300824},
#                             'southwest': {'lat': 24.7900797,
#                                           'lng': 121.2826735}}},
#   'place_id': 'ChIJmQrivHKsQjQR4MIK3c41aj8',
#   'types': ['colloquial_area', 'locality', 'political']},
#  {'address_components': [{'long_name': 'Taipei City',
#                           'short_name': 'Taipei City',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Taiwan',
#                           'short_name': 'TW',
#                           'types': ['country', 'political']}],
#   'formatted_address': 'Taipei City, Taiwan',
#   'geometry': {'bounds': {'northeast': {'lat': 25.2103038, 'lng': 121.6659421},
#                           'southwest': {'lat': 24.9605084, 'lng': 121.4570603}},
#                'location': {'lat': 25.0329636, 'lng': 121.5654268},
#                'location_type': 'APPROXIMATE',
#                'viewport': {'northeast': {'lat': 25.2103038,
#                                           'lng': 121.6659421},
#                             'southwest': {'lat': 24.9605084,
#                                           'lng': 121.4570603}}},
#   'place_id': 'ChIJi73bYWusQjQRgqQGXK260bw',
#   'types': ['administrative_area_level_1', 'political']}]

# %%
ids = []
for city in cities:
    results = []
    # Geocoding an address
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    query_result = gmaps.places_nearby(type="restaurant",location=loc, radius=10000)
    results.extend(query_result['results'])
    while query_result.get('next_page_token'):
        time.sleep(2)
        query_result = gmaps.places_nearby(page_token=query_result['next_page_token'])
        results.extend(query_result['results'])    
    print("找到以"+city+"為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): "+str(len(results)))
    for place in results:
        ids.append(place['place_id'])
# Out:
# 找到以臺北市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以新北市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以桃園市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以臺中市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以臺南市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以高雄市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以基隆市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以新竹市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以嘉義市為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以新竹縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以苗栗縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以彰化縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以南投縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以雲林縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以嘉義縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以屏東縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以宜蘭縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以花蓮縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以臺東縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60
# 找到以澎湖縣為中心半徑10000公尺的餐廳店家數量(google mapi api上限提供60間): 60

# %%
stores_info = []
# 去除重複id
ids = list(set(ids)) 
for id in ids:
    stores_info.append(gmaps.place(place_id=id, language='zh-TW')['result'])

# %%
output = pd.DataFrame.from_dict(stores_info)

# %%
stores_info[0]
# Out:
# {'address_components': [{'long_name': '277號',
#    'short_name': '277號',
#    'types': ['street_number']},
#   {'long_name': '光明一路', 'short_name': '光明一路', 'types': ['route']},
#   {'long_name': '十興里',
#    'short_name': '十興里',
#    'types': ['administrative_area_level_4', 'political']},
#   {'long_name': '竹北市',
#    'short_name': '竹北市',
#    'types': ['administrative_area_level_3', 'political']},
#   {'long_name': '新竹縣',
#    'short_name': '新竹縣',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': '台灣', 'short_name': 'TW', 'types': ['country', 'political']},
#   {'long_name': '302', 'short_name': '302', 'types': ['postal_code']}],
#  'adr_address': '<span class="postal-code">302</span><span class="country-name">台灣</span><span class="region">新竹縣</span><span class="locality">竹北市</span><span class="street-address">十興里光明一路277號</span>',
#  'business_status': 'OPERATIONAL',
#  'current_opening_hours': {'open_now': False,
#   'periods': [{'close': {'date': '2022-11-06', 'day': 0, 'time': '1430'},
#     'open': {'date': '2022-11-06', 'day': 0, 'time': '1130'}},
#    {'close': {'date': '2022-11-06', 'day': 0, 'time': '2130'},
#     'open': {'date': '2022-11-06', 'day': 0, 'time': '1700'}},
#    {'close': {'date': '2022-11-07', 'day': 1, 'time': '1400'},
#     'open': {'date': '2022-11-07', 'day': 1, 'time': '1130'}},
#    {'close': {'date': '2022-11-07', 'day': 1, 'time': '2130'},
#     'open': {'date': '2022-11-07', 'day': 1, 'time': '1730'}},
#    {'close': {'date': '2022-11-08', 'day': 2, 'time': '1400'},
#     'open': {'date': '2022-11-08', 'day': 2, 'time': '1130'}},
#    {'close': {'date': '2022-11-08', 'day': 2, 'time': '2130'},
#     'open': {'date': '2022-11-08', 'day': 2, 'time': '1730'}},
#    {'close': {'date': '2022-11-09', 'day': 3, 'time': '1400'},
#     'open': {'date': '2022-11-09', 'day': 3, 'time': '1130'}},
#    {'close': {'date': '2022-11-09', 'day': 3, 'time': '2130'},
#     'open': {'date': '2022-11-09', 'day': 3, 'time': '1730'}},
#    {'close': {'date': '2022-11-10', 'day': 4, 'time': '1400'},
#     'open': {'date': '2022-11-10', 'day': 4, 'time': '1130'}},
#    {'close': {'date': '2022-11-10', 'day': 4, 'time': '2130'},
#     'open': {'date': '2022-11-10', 'day': 4, 'time': '1730'}},
#    {'close': {'date': '2022-11-11', 'day': 5, 'time': '1400'},
#     'open': {'date': '2022-11-11', 'day': 5, 'time': '1130'}},
#    {'close': {'date': '2022-11-11', 'day': 5, 'time': '2200'},
#     'open': {'date': '2022-11-11', 'day': 5, 'time': '1730'}},
#    {'close': {'date': '2022-11-05', 'day': 6, 'time': '1430'},
#     'open': {'date': '2022-11-05', 'day': 6, 'time': '1130'}},
#    {'close': {'date': '2022-11-05', 'day': 6, 'time': '2200'},
#     'open': {'date': '2022-11-05', 'day': 6, 'time': '1700'}}],
#   'weekday_text': ['星期一: 11:30 – 14:00, 17:30 – 21:30',
#    '星期二: 11:30 – 14:00, 17:30 – 21:30',
#    '星期三: 11:30 – 14:00, 17:30 – 21:30',
#    '星期四: 11:30 – 14:00, 17:30 – 21:30',
#    '星期五: 11:30 – 14:00, 17:30 – 22:00',
#    '星期六: 11:30 – 14:30, 17:00 – 22:00',
#    '星期日: 11:30 – 14:30, 17:00 – 21:30']},
#  'delivery': True,
#  'dine_in': True,
#  'formatted_address': '302台灣新竹縣竹北市光明一路277號',
#  'formatted_phone_number': '03 552 0158',
#  'geometry': {'location': {'lat': 24.8315388, 'lng': 121.0104437},
#   'viewport': {'northeast': {'lat': 24.8329326302915,
#     'lng': 121.0118206302915},
#    'southwest': {'lat': 24.8302346697085, 'lng': 121.0091226697085}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'international_phone_number': '+886 3 552 0158',
#  'name': '新橋燒肉屋 竹北店',
#  'opening_hours': {'open_now': False,
#   'periods': [{'close': {'day': 0, 'time': '1430'},
#     'open': {'day': 0, 'time': '1130'}},
#    {'close': {'day': 0, 'time': '2130'}, 'open': {'day': 0, 'time': '1700'}},
#    {'close': {'day': 1, 'time': '1400'}, 'open': {'day': 1, 'time': '1130'}},
#    {'close': {'day': 1, 'time': '2130'}, 'open': {'day': 1, 'time': '1730'}},
#    {'close': {'day': 2, 'time': '1400'}, 'open': {'day': 2, 'time': '1130'}},
#    {'close': {'day': 2, 'time': '2130'}, 'open': {'day': 2, 'time': '1730'}},
#    {'close': {'day': 3, 'time': '1400'}, 'open': {'day': 3, 'time': '1130'}},
#    {'close': {'day': 3, 'time': '2130'}, 'open': {'day': 3, 'time': '1730'}},
#    {'close': {'day': 4, 'time': '1400'}, 'open': {'day': 4, 'time': '1130'}},
#    {'close': {'day': 4, 'time': '2130'}, 'open': {'day': 4, 'time': '1730'}},
#    {'close': {'day': 5, 'time': '1400'}, 'open': {'day': 5, 'time': '1130'}},
#    {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1730'}},
#    {'close': {'day': 6, 'time': '1430'}, 'open': {'day': 6, 'time': '1130'}},
#    {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1700'}}],
#   'weekday_text': ['星期一: 11:30 – 14:00, 17:30 – 21:30',
#    '星期二: 11:30 – 14:00, 17:30 – 21:30',
#    '星期三: 11:30 – 14:00, 17:30 – 21:30',
#    '星期四: 11:30 – 14:00, 17:30 – 21:30',
#    '星期五: 11:30 – 14:00, 17:30 – 22:00',
#    '星期六: 11:30 – 14:30, 17:00 – 22:00',
#    '星期日: 11:30 – 14:30, 17:00 – 21:30']},
#  'photos': [{'height': 1108,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105218004800472103192">新橋燒肉屋 竹北店</a>'],
#    'photo_reference': 'AW30NDymqH-96fsqUSLmTfIK8I57A7p26I6K3wLQsIxpR-Ik-pEU3oGCk1Lv5SZi6n_6BeMlgmFHGRcwWCXw8z4ldtmcZ-3_VD0AD3gATNyxDFoXZ63ewr5iT1sy_mg3DQWD95NnsmXgeLT2bhJJ2mJ1nH4Q3IA86wtGViCJbOs5BM8qpHw',
#    'width': 1409},
#   {'height': 2448,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105218004800472103192">新橋燒肉屋 竹北店</a>'],
#    'photo_reference': 'AW30NDyj6UfuJ5ie8dWWv2bOxrxWKhye6phywyNvD7FxLWaEUjX0BXVxKRfbYF-uo-2gE5AcXQe6G85OGSFKWwHWB2ZGUhZhW3kn1L3i-GRwcl7epD0OaWr7tTwlaC5dA_d1BfK8_uc7mhxSu_3A6OIl4Q57hlZX4bEJRKMMGuKaG5ycUiI',
#    'width': 3264},
#   {'height': 3096,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112651141632634150140">patrick chen</a>'],
#    'photo_reference': 'AW30NDx8XgsQL0qCj7iFsptqZG8myl3Aj0quiQxNyccbXlWVpNmZcddxavO7BOlfsnDDNu1Fte8vS0sk1OvLKJKXWHhhAUL9iP1xcm_g-sjrNCU1Wm0_LcBRpfZCPdcf0zLiAIsshYQVgVjBU_iljmWYKChKQXNqoG6Z9clQjGL1Ky8n0NFg',
#    'width': 5504},
#   {'height': 2604,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107693122325585236644">彭駿堯</a>'],
#    'photo_reference': 'AW30NDymDeBwEiKdp0wHv3PdKHgcisyfZIysQIXyWsVahN3E_dSTwwTw4lcdugjzjljyWkIl7tUqQp9t_cT90LENudRpcYT7Ca-9tCG0LqWRlMiv00K3d3RTrc-XRVhwpO1ueaeTjOQsUvht-HaWCWiNrxJ12eiokvIGZRDtVR990t-Zx9oa',
#    'width': 4624},
#   {'height': 2933,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107316256637830745722">翊軒黃</a>'],
#    'photo_reference': 'AW30NDxpZqtRsfl57l4YEVB-z6v1Vj2v0Yd_KiWORkTWf4__6kIWt_GQvuhKBeMArVkcBI3FYXUMjdhyuBvXsF9jmjNaoOoQQszqc7-1ewqAjS4H9EpgKzmJ7LgnNiqaOWX38O7UWcClr-OX3qM1vFwYdW6xIOjfRqO4ATQuEftx7UPs8RsL',
#    'width': 3913},
#   {'height': 2514,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109730941473770723178">黃建鈞</a>'],
#    'photo_reference': 'AW30NDxEyxuGyB0NW9g2bP2x3-jdRKL4DytFIrfSqADYB6cGyLZPwPrOHJiFL3HGxf1F01CuKF8DjW_oBntxBzai576T2aTegYEdvGZKtvhMEH_ulbhTa4hlarJTEvuvL2YDAUpATnnob14eU5NhsE7xU81vNNLwoZH30EqNv6Wg5223xBFL',
#    'width': 3445},
#   {'height': 9000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100938904850982257734">雅兒</a>'],
#    'photo_reference': 'AW30NDy58xvUMTasKk_UFCEvERS74XvH1SCiKKAbtcdxNlcL-66U2hxdiQV-6uR4lFq_mvssxHGaBHFAJrBKgRQe_PVSMK66taIOybnEIUSoljYTlV8GgaQmqVqjlGGY_ymeof2fsKE5WoyWRS8F2adIXeq7-e8zvgJvcu4aDMNfUwsRWf5M',
#    'width': 12000},
#   {'height': 9000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100938904850982257734">雅兒</a>'],
#    'photo_reference': 'AW30NDx82R_SfeHofT5bX_iEW_sVnJo4MePNNVu7SWZiDCZVkHYz7ksjbbcw0OyYyuPJ56wE8Fy0rbmru3pITqQCnj-YDKunDDRCnnlbzUWvusXUrGbU8Xcr4U-ML1lmGRu0JrIk_U9WLZqfUt6gGIajQKo484t-bmp3ZLe9RLlvg1Ekh3RI',
#    'width': 12000},
#   {'height': 3024,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102318655987040077071">林鈺舜（Derek Lin）</a>'],
#    'photo_reference': 'AW30NDy4-k4O6UDaDobpZLjB5r1Fllcn0ZaaRx35MVDxKdr07Zbe8mlbKGJelPQuoYjgNi-ecHE9rShZaSZ9kXqftFj9FxKBJGasY1kbX5ScwpLiSqetVpQsWlwwm1IC_EBp-o2WNAWLXuKQcBhnpkyIh5ZbJz0TOPFnZTg_ZmWcbpUb2A_5',
#    'width': 4032},
#   {'height': 3024,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113969338192029067517">Celia Chen</a>'],
#    'photo_reference': 'AW30NDwKAbzC6YIBH45fZAUFfIk4Cz4ALi8Ku8fyYXpB5zaJ1EWW5BlHLUrdAHNV7n4kpdYoAUZq7gVmlM0qOBcj_C61pNrcPc3QzY7Uiphq6Y9Y1drBhqf6C85sFgLtUjaJYQx3iKRbqWCCUk-HdmSpursoxkOVwZYloJfvSKxWOukLbIih',
#    'width': 4032}],
#  'place_id': 'ChIJZbL0spQ2aDQR5871gjBqEDM',
#  'plus_code': {'compound_code': 'R2J6+J5 台灣新竹縣竹北市',
#   'global_code': '7QP3R2J6+J5'},
#  'price_level': 2,
#  'rating': 4.3,
#  'reference': 'ChIJZbL0spQ2aDQR5871gjBqEDM',
#  'reviews': [{'author_name': '黃建鈞',
#    'author_url': 'https://www.google.com/maps/contrib/109730941473770723178/reviews',
#    'language': 'zh-Hant',
#    'original_language': 'zh-Hant',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a/ALm5wu14p3BtyteUSeXe1lEIr3KQOdF-ARmrwSUcmQKQ=s128-c0x00000000-cc-rp-mo-ba5',
#    'rating': 4,
#    'relative_time_description': '3 個月前',
#    'text': '食材、環境、服務，均有其水準。\n\n食材屬於中高階的層級，\n\n雖未臻至絕頂，但也完全對得起它的價格水平，聰明且恰如其分的客群定位。\n\n店址緊鄰公設地下停車場，停車便利不在話下。\n\n惟假日用餐時段需常態性的候位，\n\n平均約1至1.5小時左右，\n\n且訂位與否也似無實質差異。\n\n當天提前大約6小時訂位時，要等一個多小時，\n\n無訂位時也要等一個多小時。 這部份建議需斟酌提前預約，\n當日或臨時預約，應該都無法獲得省時的實質紅利。\n\n廁所數量有些吃緊，幾乎每次都需要排隊等廁所，\n\n外場服務員似乎人手與服務量能稍嫌不足，欲加點食材或需要服務員時，\n\n服務員通常常態性的因忙碌而無視，有時招呼示意了三四次才會被注意到。\n\n餐盤與擺設的葉子，潔淨度尚須加強，也許來客量大，\n\n但有時盤碟與擺設用葉確實有明顯的水垢殘漬，看上去易讓人產生疑慮，\n\n究竟這只是單純水漬、還是乾燥過後的油垢與洗潔精？\n我想除非真的檢驗，否則可能也沒人知道。\n\n而肉片就這樣擺在上頭，吃或不吃？反映或不反映？  坦白說都很掙扎猶豫。\n\n既不想反映，顯得好像在刁難這種雞毛蒜皮的小事，而服務人員每位看似都已忙到忘我，\n\n然而，確實看在眼裡又頗有腦海中的發酵，\n\n只能憑當下的心態去吸收與面對。\n\n另外特別希望改善服務動能不足的問題，\n\n這是單點性質的燒烤，應該在服務量能上，可以更加從容為佳，\n\n而目前看起來與吃到飽那種充滿各種忙碌、延宕、緊湊的「武市」性質幾無二致。\n\n若可以獲得改善，用餐體驗會更臻完美。',
#    'time': 1657473494,
#    'translated': False},
#   {'author_name': 'Shan Chang',
#    'author_url': 'https://www.google.com/maps/contrib/115558247541145221217/reviews',
#    'language': 'zh-Hant',
#    'original_language': 'zh-Hant',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACNPEu-6UJxHPy63yPBgBy2yYjVNxKLhVqosg4vZ5gTuTQ=s128-c0x00000000-cc-rp-mo-ba5',
#    'rating': 5,
#    'relative_time_description': '7 個月前',
#    'text': '第一次用餐覺得真的是很不錯的一家店～\n平日晚間沒有預約一下子就進去了沒有過久的等候～（但還是建議要預約確保有沒有位置哦！）\n一上桌就會附雞湯與生菜 都是無限續的哦！\n雞湯味道很讚！跟朋友都喝掉一壺了哈哈哈😆\n服務人員也都很親切！再烤干貝時還會來提醒甚至親自操作加雞湯會更好吃😋\n個人覺得厚切牛舌真的是極品！\n雖然價格高了一些但很值得去嘗試❤️\n附近停車也很方便 CP值還蠻高的👍',
#    'time': 1648199316,
#    'translated': False},
#   {'author_name': 'Ivy Ip',
#    'author_url': 'https://www.google.com/maps/contrib/116875022733764157340/reviews',
#    'language': 'zh-Hant',
#    'original_language': 'zh-Hant',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a/ALm5wu371ApU57pCOCAW9C92sNhGHTqUWuEzrxORmC_9B2g=s128-c0x00000000-cc-rp-mo-ba3',
#    'rating': 4,
#    'relative_time_description': '1 週前',
#    'text': '吃CP值的店 雙人精緻套餐也才一千\n\n肉：因為幾乎都是腌過的 所以只要肉質不太差 都不會難吃\n\n雞湯：比屋馬的淡 比較像是粥的高湯底的口味\n\n套餐組合：建議換掉杏鮑菇跟海鮮盤裡的小魚干這兩項明顯為了湊數而加的品項 吃下去只會讓人想扣分\n\n停車：附近很多停車場 停車方便\n\n其他：因為沒有那種放盤子用的架子 所以桌面會很擠 有壓力要趕快清掉桌上的盤子 不然後面的會放不下',
#    'time': 1666490881,
#    'translated': False},
#   {'author_name': 'Ally Hsu',
#    'author_url': 'https://www.google.com/maps/contrib/112025786432548006648/reviews',
#    'language': 'zh-Hant',
#    'original_language': 'zh-Hant',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACNPEu9EWrrmrDyK-21yKXFl4eSApJx0VgSTUjY4gLNWxw=s128-c0x00000000-cc-rp-mo-ba3',
#    'rating': 5,
#    'relative_time_description': '8 個月前',
#    'text': '從小吃到大的店～建議一定要預約！雖然沒有吃過很多家，但是是目前吃過當中CP值高的店，肉質中等，但是調味都還不錯！生菜、雞湯都是無限續，雞湯很好喝，如果有點干貝 加進去烤完後更好喝(另一種風味)，雞腿肉推薦味增口味的，抹茶紅豆冰淇淋幾乎每次來必點，蜜紅豆和濃濃的抹茶真的很搭！飯後的甜點是紫米(一直以來都沒變)，服務員態度很好，非常積極換烤網還有收拾空盤，然後附近有一個大停車場停車蠻方便的。',
#    'time': 1645095048,
#    'translated': False},
#   {'author_name': '阿呆',
#    'author_url': 'https://www.google.com/maps/contrib/104312727833253239500/reviews',
#    'language': 'zh-Hant',
#    'original_language': 'zh-Hant',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACNPEu-EZiE0cZ-wHbb9PYHkjfqtla_8090kCNOrxhl5DQ=s128-c0x00000000-cc-rp-mo',
#    'rating': 5,
#    'relative_time_description': '3 個月前',
#    'text': '感謝志偉店員教我怎麼考厚切牛舌以及替我考海大蝦！能被這麼好的店員服務真的是深感榮幸^^\n厚切牛舌真的非常好吃\n（前提是要會抓熟度）',
#    'time': 1658228632,
#    'translated': False}],
#  'takeout': True,
#  'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=3679557652149817063',
#  'user_ratings_total': 3030,
#  'utc_offset': 480,
#  'vicinity': '竹北市光明一路277號'}

# %%
output
# Out:
#                                      address_components  \
# 0     [{'long_name': '277號', 'short_name': '277號', '...
# 1     [{'long_name': '721號', 'short_name': '721號', '...
# 2     [{'long_name': '2F', 'short_name': '2F', 'type...
# 3     [{'long_name': '16之2號', 'short_name': '16之2號',...
# 4     [{'long_name': '105號', 'short_name': '105號', '...
# ...                                                 ...
# 1195  [{'long_name': '號', 'short_name': '號', 'types'...
# 1196  [{'long_name': '644號', 'short_name': '644號', '...
# 1197  [{'long_name': '37號', 'short_name': '37號', 'ty...
# 1198  [{'long_name': '仁三路', 'short_name': '仁三路', 'ty...
# 1199  [{'long_name': '320號', 'short_name': '320號', '...
#
#                                             adr_address     business_status  \
# 0     <span class="postal-code">302</span><span clas...         OPERATIONAL
# 1     <span class="postal-code">504</span><span clas...         OPERATIONAL
# 2     <span class="postal-code">800</span><span clas...         OPERATIONAL
# 3     <span class="postal-code">923</span><span clas...         OPERATIONAL
# 4     <span class="postal-code">80241</span><span cl...         OPERATIONAL
# ...                                                 ...                 ...
# 1195  <span class="postal-code">632</span><span clas...         OPERATIONAL
# 1196  <span class="postal-code">970</span><span clas...         OPERATIONAL
# 1197  <span class="postal-code">110</span><span clas...         OPERATIONAL
# 1198  <span class="postal-code">200</span><span clas...         OPERATIONAL
# 1199  <span class="postal-code">403</span><span clas...  CLOSED_TEMPORARILY
#
#                                   current_opening_hours delivery dine_in  \
# 0     {'open_now': False, 'periods': [{'close': {'da...     True    True
# 1     {'open_now': False, 'periods': [{'close': {'da...     True    True
# 2     {'open_now': False, 'periods': [{'close': {'da...     True    True
# 3     {'open_now': False, 'periods': [{'close': {'da...      NaN    True
# 4     {'open_now': False, 'periods': [{'close': {'da...     True    True
# ...                                                 ...      ...     ...
# 1195  {'open_now': False, 'periods': [{'close': {'da...      NaN    True
# 1196  {'open_now': True, 'periods': [{'close': {'dat...      NaN    True
# 1197  {'open_now': False, 'periods': [{'close': {'da...     True    True
# 1198  {'open_now': True, 'periods': [{'close': {'dat...    False    True
# 1199                                                NaN    False    True
#
#               formatted_address formatted_phone_number  \
# 0           302台灣新竹縣竹北市光明一路277號            03 552 0158
# 1          504台灣彰化縣秀水鄉彰水路一段721號           0909 727 467
# 2         800台灣高雄市新興區中山二路472號2F            07 282 0712
# 3           923台灣屏東縣萬巒鄉三多路16之2號            08 781 3195
# 4         80241台灣高雄市苓雅區文橫二路105號            07 335 3353
# ...                         ...                    ...
# 1195     632台灣雲林縣虎尾鎮民主十二路11-1號號            05 632 6985
# 1196         970台灣花蓮縣花蓮市中正路644號            03 836 0340
# 1197     110台灣台北市信義區光復南路417巷37號           02 2345 1398
# 1198  200台灣基隆市仁愛區仁三路60號左前(16號攤位           0986 686 617
# 1199       403台灣台中市西區台灣大道二段320號                    NaN
#
#                                                geometry  \
# 0     {'location': {'lat': 24.8315388, 'lng': 121.01...
# 1     {'location': {'lat': 24.0508041, 'lng': 120.51...
# 2     {'location': {'lat': 22.6203771, 'lng': 120.30...
# 3     {'location': {'lat': 22.5645877, 'lng': 120.55...
# 4     {'location': {'lat': 22.61951389999999, 'lng':...
# ...                                                 ...
# 1195  {'location': {'lat': 23.7035223, 'lng': 120.43...
# 1196  {'location': {'lat': 23.9812901, 'lng': 121.61...
# 1197  {'location': {'lat': 25.0369568, 'lng': 121.55...
# 1198  {'location': {'lat': 25.1286292, 'lng': 121.74...
# 1199  {'location': {'lat': 24.1536144, 'lng': 120.66...
#
#                                                    icon  ...  \
# 0     https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 1     https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 2     https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 3     https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 4     https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# ...                                                 ...  ...
# 1195  https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 1196  https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 1197  https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 1198  https://maps.gstatic.com/mapfiles/place_api/ic...  ...
# 1199  https://maps.gstatic.com/mapfiles/place_api/ic...  ...
#
#                                                   types  \
# 0     [bar, restaurant, food, point_of_interest, est...
# 1     [restaurant, point_of_interest, food, establis...
# 2     [restaurant, food, point_of_interest, establis...
# 3     [restaurant, food, point_of_interest, establis...
# 4     [meal_takeaway, store, restaurant, point_of_in...
# ...                                                 ...
# 1195  [restaurant, point_of_interest, food, establis...
# 1196  [restaurant, food, point_of_interest, establis...
# 1197  [restaurant, food, point_of_interest, establis...
# 1198  [store, restaurant, food, point_of_interest, e...
# 1199  [restaurant, food, point_of_interest, establis...
#
#                                                     url user_ratings_total  \
# 0      https://maps.google.com/?cid=3679557652149817063             3030.0
# 1      https://maps.google.com/?cid=8692899920349748739              130.0
# 2      https://maps.google.com/?cid=1866723787436995683             3544.0
# 3     https://maps.google.com/?cid=16754891110433311703                2.0
# 4      https://maps.google.com/?cid=8018991418252023198             2256.0
# ...                                                 ...                ...
# 1195   https://maps.google.com/?cid=8318990182621984942               85.0
# 1196   https://maps.google.com/?cid=5449439322102741559             3211.0
# 1197   https://maps.google.com/?cid=1140287619445676510              383.0
# 1198   https://maps.google.com/?cid=3199875014739776296              320.0
# 1199   https://maps.google.com/?cid=1454102862606687761             2276.0
#
#      utc_offset                 vicinity  \
# 0           480              竹北市光明一路277號
# 1           480             秀水鄉彰水路一段721號
# 2           480  2F, No. 472號, 中山二路, 新興區
# 3           480              萬巒鄉三多路16之2號
# 4           480              苓雅區文橫二路105號
# ...         ...                      ...
# 1195        480           虎尾鎮民主十二路11-1號號
# 1196        480               花蓮市中正路644號
# 1197        480           信義區光復南路417巷37號
# 1198        480        仁愛區仁三路60號左前(16號攤位
# 1199        480             西區台灣大道二段320號
#
#                                                 website editorial_summary  \
# 0                                                   NaN               NaN
# 1                  https://www.facebook.com/SuBuChi2nd/               NaN
# 2                             https://www.tasty.com.tw/               NaN
# 3                                                   NaN               NaN
# 4                         http://www.bite2eatpizza.com/               NaN
# ...                                                 ...               ...
# 1195  https://www.facebook.com/frunchrestaurant/?fre...               NaN
# 1196                    https://www.facebook.com/OS0001               NaN
# 1197  https://zh-tw.facebook.com/pages/%E7%B1%8C%E5%...               NaN
# 1198                                                NaN               NaN
# 1199                       http://www.ponderosa.com.tw/               NaN
#
#      permanently_closed  curbside_pickup  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ...                 ...              ...
# 1195                NaN              NaN
# 1196                NaN              NaN
# 1197                NaN              NaN
# 1198                NaN             True
# 1199               True            False
#
#                                 secondary_opening_hours
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
# 1198                                                NaN
# 1199  [{'open_now': False, 'periods': [{'close': {'d...
#
# [1200 rows x 33 columns]

# %%
output.columns
# Out:
# Index(['address_components', 'adr_address', 'business_status',
#        'current_opening_hours', 'delivery', 'dine_in', 'formatted_address',
#        'formatted_phone_number', 'geometry', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'international_phone_number', 'name',
#        'opening_hours', 'photos', 'place_id', 'plus_code', 'price_level',
#        'rating', 'reference', 'reviews', 'takeout', 'types', 'url',
#        'user_ratings_total', 'utc_offset', 'vicinity', 'website',
#        'editorial_summary', 'permanently_closed', 'curbside_pickup',
#        'secondary_opening_hours'],
#       dtype='object')

# %%
output["place_id"]
# Out:
# 0       ChIJZbL0spQ2aDQR5871gjBqEDM
# 1       ChIJiTo83KxHaTQRA953rGtio3g
# 2       ChIJTU1fToEEbjQRYzT082Tv5xk
# 3       ChIJqW7NyCAibjQR10u6l7FUheg
# 4       ChIJA7wegIAEbjQRnlXRXTUuSW8
#                    ...
# 1195    ChIJp-AlmQC6bjQRrjglxX79cnM
# 1196    ChIJL9Bd-cOfaDQRN7r66jBMoEs
# 1197    ChIJ0RrGQ8irQjQR3tnVYowd0w8
# 1198    ChIJzZiNZz5OXTQRKFM2S189aCw
# 1199    ChIJ15Ppz3c9aTQREd6McNkCLhQ
# Name: place_id, Length: 1200, dtype: object
